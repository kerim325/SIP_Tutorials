# %% [markdown]
# # Signal and Image Processing (SIP_SS23)
# ###  Convolution and Discrete Fourier Transform Tutorial
#
# Lecturer: Prof Moritz GROSSE-WENTRUP
#
# Tutorial by: Sadiq Adewale ADEDAYO and Jakob Prager

# %%
# imports packages required (Numpy and Matplotlib)

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1 - Discrete Fourier Transform (DFT)

# %% [markdown]
# You have learned about the analysis (DFT) and synthesis (iDFT) from the video lectures. We have introduced that DFT allows us to change the basis of a signal from time to frequency domain while iDFT does the reverse.
#
# In this exercise, we will implement this and see how the concept works.
#
# Recall,
#
# Discrete Fourier Transform (Analysis); $$X(k) = \sum_{n=0}^{N-1} x[n] \exp \left( {-j.\frac{ 2\pi k}{N}. n} \right)$$
#
#
# inverse Discrete Fourier Transform (Synthesis); $$x[n] = \frac{1}{N} \sum_{k=0}^{N-1} X(k) \exp \left( {j.\frac{ 2\pi k}{N}. n} \right)$$

# %% [markdown]
# ### Trigonometric signals
#
# Before we dive into DFT, it is important to understand the conscept of oscilations in a signal
#
#
# Take for instance a sine signal as defined by;
# $$x[n] = A sin\left( \frac{2 \pi k}{N}. n  \right)$$
#
# - where A is the amplitude
# - k is the frequency of oscilations per second measure in $s^{-1}$ or Hz. Intuitively, k is tzhe number of comnplete periods within N. i.e. if the signal is 1 second long, then k is the frequency.
# - N is the signal lenght per second. i.e., number of samples in the signal in one second.
#
# Hence in the formula, we can also have the following if the sampling frequency is given,
#
# i.e., $$x[n] = A sin\left( \frac{2 \pi k}{f_{s}}. n  \right)$$

# %%
# generate sine signals s1 and s2

N = 1000 # in this case we use 1 second long signal of length N
n = np.arange(N)

k1 = 1 # for s1, 
k2 = 50 # for s2

s1 = np.sin(2 * np.pi * k1 / N * n)
s2 = np.sin(2 * np.pi * k2 / N * n)

# %%
# plot sine signals

fig, ax = plt.subplots(2,1)
ax[0].plot(s1)
ax[0].grid()
ax[0].set_xlabel('n')
ax[0].set_ylabel('$s_{1}[n]$', rotation=60)

ax[1].plot(s2)
ax[1].grid()
ax[1].set_xlabel('n')
ax[1].set_ylabel('$s_{2}[n]$', rotation=60)
# Out:
# Text(0, 0.5, '$s_{2}[n]$')

# %%
# carry out some operation on signals eg addition of two signals for instance
k3, k4 =  5, 50 

s3 = 2 * np.sin(2 * np.pi *k3 /N * n) + np.sin(2 * np.pi * k4/N * n)  # note the amplitudes
 
# plot

plt.figure(figsize=(15,5))
plt.plot(s3, label='$s_{3}$')
plt.plot(2 * np.sin(2 * np.pi * k3 /N * n), label='k=5')
plt.plot(np.sin(2 * np.pi * k4/N * n), label='k=50')
plt.title('Addition of two sine waves')
plt.grid()
plt.legend()

# %% [markdown]
# Implement both DFT and iDFT as functions.

# %%
# DFT
def DFT(x):
    """
    input: signal x[n] in time domain
    output: X(f) in frequency domain
    """
    N = len(x)
    n = np.arange(0,N)
    F = np.exp(-1j * 2 * np.pi/N * np.outer(n, n))   # hint: use np.outer(n,n) for the basis vectors
    return np.dot(F, x)


# inverse DFT
def iDFT(X):
    """
    input: signal X(f) in frequency domain
    output: x[n] in time domain
    """
    N = len(X)
    n = np.arange(0,N)
    IF = np.exp(1j* 2 * np.pi/N * np.outer(n, n))/ N    # hint: use np.outer(n,n) for the basis vectors
    return np.dot(IF, X)

# %%
# application on signals generated above

S1 = DFT(s1)
S2 = DFT(s2)
S3 = DFT(s3)

# %%
# plots


fig, ax = plt.subplots(3, 2, figsize=(15,9))
ax[0, 0].plot(np.abs(S1))
ax[0, 0].grid()
ax[0, 0].set_title('Amplitude')

ax[0, 1].plot(np.angle(S1))
ax[0, 1].grid()
ax[0, 1].set_title('Phase')


ax[1, 0].plot(np.abs(S2))
ax[1, 0].grid()
ax[1, 0].set_title('Amplitude')

ax[1, 1].plot(np.angle(S2))
ax[1, 1].grid()
ax[1, 1].set_title('Phase')


ax[2, 0].plot(np.abs(S3))
ax[2, 0].grid()
ax[2, 0].set_title('Amplitude')

ax[2, 1].plot(np.angle(S3))
ax[2, 1].grid()
ax[2, 1].set_title('Phase')

plt.tight_layout()

# %% [markdown]
# When time domain signal e.g `x[n]`, is converted into frequency domain `X(f)` via DFT, the resulting spectrum is a complex. i.e it has both amplitude and phase which we can characterise the spectrum of the signal. Oftentimes, signals may have the same amplitude spectrum but different phase plots as in sine and cosine signal.
#
# It is also worth noting, because there are both positive and negative frequencies, the amplitude spectrum is ploted symmetric and a special function `numpy.fft.fftshift()` should be used. To have the same effect on the phase plot, we use `numpy.unwrap()` on the phase.

# %%
fig, ax = plt.subplots(3, 2, figsize=(15,9))
ax[0,0].plot(np.linspace(-N/2,N/2,N), np.fft.fftshift(np.abs(S1)))
ax[0,0].grid()
ax[0,0].set_title('Amplitude')

ax[0,1].plot(np.linspace(-N/2,N/2,N), np.unwrap(np.angle(S1)))
ax[0,1].grid()
ax[0,1].set_title('Phase $s_{1}$')

ax[1,0].plot(np.linspace(-N/2,N/2,N), np.fft.fftshift(np.abs(S2)))
ax[1,0].grid()
ax[1,0].set_title('Amplitude')

ax[1,1].plot(np.linspace(-N/2,N/2,N), np.unwrap(np.angle(S2)))
ax[1,1].grid()
ax[1,1].set_title('Phase $s_{2}$')

ax[2, 0].plot(np.linspace(-N/2,N/2,N), np.fft.fftshift(np.abs(S3)))
ax[2, 0].grid()
ax[2, 0].set_title('Amplitude')

ax[2, 1].plot(np.linspace(-N/2,N/2,N), np.unwrap(np.angle(S3)))
ax[2, 1].grid()
ax[2, 1].set_title('Phase $s_{3}$')

plt.tight_layout()

# %% [markdown]
# We now implement a iDFT function. Provide the equation for the transformation matrix

# %% [markdown]
# ## 2 - Convolution
#
# Convolution operation in signal processing expresses the amount of overlap of one signal shifted over another. As notation, we adopt commonly used representations such as `y[n]` as result or output of convolution, `x[n]` as the signal and `h[n]` as impulse response of the system in which `x[n]` is fed into.
#
# #### In this part, we will only implement linear convolutions of discrete signals as discussed in the lecture.
#
# Note: There exist `linear` and `circular` convolutions, but for sake of this tutorial, we will focus on implementing linear convolution. You are encouraged to look up on circular convolution on their own free will.
#
# You are also encouraged to use the hints provided to solve the task. Please note, this implementation is not optimized for run time, hence more time efficient implementations exist as that of [np.convolve()](https://numpy.org/doc/stable/reference/generated/numpy.convolve.html) and [scipy.signal.convolve()](https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.convolve.html)

# %% [markdown]
# $$y[n] = x[n] * h[n] = \sum_{- \infty}^{\infty} x[k] . h[n - k] $$

# %% [markdown]
# In the following code cell, write a function to compute linear convolution `lin_convolution(x, h)` that takes two inputs; signal `x[n]` and impulse response `h[n]` and computes and return the convolved signal `y[n]`. In this case, we will also only explore the mode where one of the signals slide over the other completely, i.e., `mode = full` in [np.convolve(mode='full')](https://numpy.org/doc/stable/reference/generated/numpy.convolve.html) implementations.
#
# #### You are encouraged to further the impolementation to achieve the other results as in `mode = same` and `mode = valid` as in Numpy

# %%
def lin_convolution(x, h):
    # determine the size of convolution output
    N = len(x) + len(h)-1
    
    # initialize array of zeros for the output signal
    y = np.zeros(N)
    
    # determine number of zeros required to pad both `x[t]` and `h[t]`, i and j respectively
    i,j = N - len(x), N - len(h)
    
    # zero-pad x[t] and h[t] to the same size
    x_padded = np.pad(x, (0,i), 'constant')
    h_padded = np.pad(h, (0,j), 'constant')

    
    for n in range(N):
        for k in range(N):
            if n >= k:
                 y[n] += x_padded[n-k]*h_padded[k] 
                    
    return y

# %% [markdown]
# Next, we will test `lin_convolution(x, h)` with some signals and compare the results with that of numpy implementation.
#
# For sake of uniformity, we will take `x[n]` = [0, 1, 2, 1] and `h_[t]` = [2, 2, 1, 1].
#
# We would expect our function to return `y[n]` = [2, 6, 5, 5, 4, 1, 1] which is the same as using `np.convolve(x, h, mode = 'full')`.
#
# After we confirmed our funtion is working properly, we can then try out other various signals of various lengths.

# %%
# test cells for the `lin_convolution()`

x = [1, 2, 0, 1]
h = [2, 2, 1, 1]

y = lin_convolution(x, h)  # call the written function here on x and h 

y_np = np.convolve(x, h, mode = 'full')

# %%
# plots

# For adequate visualization of results, we will use the stem plot from matplotlib 

fig, ax = plt.subplots(1, 2, figsize = (12, 4))
ax[0].stem(y)
ax[0].set_title('Implemented linear convolution')
ax[0].set_xlabel('n')
ax[0].set_ylabel('y[n]', rotation=60)
ax[0].grid()

ax[1].stem(y_np)
ax[1].set_title('Numpy implementation')
ax[1].set_xlabel('n')
ax[1].set_ylabel('$y_{np}[n]$', rotation=60)
ax[1].grid()
plt.tight_layout()

# %%
# More tests

# %% [markdown]
# ### Conclusions
#
# We explore Discrete Fourier Transform (DFT) and convolution theorem in this tutorial. You are encouraged to look out other use cases to cement your understanding of thee concepts. Bellow are some bonus tasks for your practice.

# %% [markdown]
# ## Bonus tasks
#
# These tasks are given for more hands-on engagement of students. There will be no solutions or grading (i.e., they are only for students to explore for leisure).
#
#
# 1. Show that the convolution operation fulfills the following properties
#  - Commutative i.e., $\quad x[n] * h[n] = h[n] * x[n]$
#
#  - Associative i.e., $\quad (x_{1}[n] * h[n]) * x_(2)[n] = x_{1}[n] * (h[n] * x_{2}[n])$
#
#  - Derrivative i.e., $\quad y[n] = x[n] * h[n]$
#
#  $\quad\quad\quad\quad\quad\quad$ $\frac{dy[n]}{dn} = \frac{dx[n]}{dn} * h[n] = \frac{dh[n]}{dn} * x[n]$.
#
#
#
# 2. Show that convolution in spatial (time) domain is same as convolution in spectral (frequency) domain
#
#  $$x[n] * h[n] = X(f) * H(f)$$
#
#  where `x[n]` and `h[n]` and signal `x` and impulse `h` in time domain
#
#      and `X[f]` and `H[f]` are the spectral domain of `x` and `h` respectively.
#
#
#
# 3. Let $x[n] = \sum\limits_{k\in \{10, 50, 100, 150, 200\}} \cos(2\pi \frac{k}{f_{s}}n)$ with $n \in [0, 999]$ and sampling frequency $f_s = 500$Hz.
#
# > Plot $x[n]$, its frequency spectrum $|X(f)|$, and $\angle X(f)$.
# > #### Hint:  Since $X(f)$ is a complex-valued signal, you can either plot its real- and imaginary part separately or use 3D plot.
